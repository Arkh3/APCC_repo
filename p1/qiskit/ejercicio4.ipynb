# %% [markdown]
# # Ejecutado en ibmq_belem (5 qbits, 16 de volumen cuántico)

# %%
import numpy as np
from qiskit import IBMQ
from qiskit.compiler import assemble, transpile
IBMQ.save_account('f33574e4ee70dc79fa2cc13196842a585bd84475ea12349568c2c649874d3a9bec1c6b58c70de7d7406b83d41b26368d0fd6ec73671834b56911a6f0cbbb1c31')
from qiskit import(
  QuantumCircuit,
  execute,
  Aer)
# Out:
# configrc.store_credentials:WARNING:2021-03-11 11:21:00,926: Credentials already present. Set overwrite=True to overwrite.

# %%
circuit = QuantumCircuit(3, 3)
circuit.h(0)
circuit.cx(0, 1)
circuit.cx(1, 2)
circuit.measure([0,1,2], [0,1,2])

provider = IBMQ.load_account()
backend = provider.backends.ibmq_belem
qobj = assemble(transpile(circuit, backend=backend), backend=backend)
job = backend.run(qobj)
retrieved_job = backend.retrieve_job(job.job_id())


result = job.result()

counts = result.get_counts(circuit)
print("\nNúmero de ocurrencias: ",counts)
# Out:
# Número de ocurrencias:  {'000': 465, '001': 19, '010': 8, '011': 19, '100': 8, '101': 27, '110': 48, '111': 430}

# %% [markdown]
# ![circuit-klvca9cu.png](attachment:circuit-klvca9cu.png)

# %% [markdown]
# ![bar-chart.png](attachment:bar-chart.png)

# %% [markdown]
# # Ejecutado en ibmq_lima (5 qbits, 8 de volumen cuántico)

# %%
circuit = QuantumCircuit(3, 3)
circuit.h(0)
circuit.cx(0, 1)
circuit.cx(1, 2)
circuit.measure([0,1,2], [0,1,2])

provider = IBMQ.load_account()
backend = provider.backends.ibmq_lima
qobj = assemble(transpile(circuit, backend=backend), backend=backend)
job = backend.run(qobj)
retrieved_job = backend.retrieve_job(job.job_id())


result = job.result()

counts = result.get_counts(circuit)
print("\nNúmero de ocurrencias: ",counts)
# Out:
# ibmqfactory.load_account:WARNING:2021-03-11 11:34:48,627: Credentials are already in use. The existing account in the session will be replaced.
# Número de ocurrencias:  {'000': 520, '001': 7, '010': 3, '011': 21, '100': 3, '101': 21, '110': 13, '111': 436}

# %% [markdown]
# ![bar-chart.png](attachment:bar-chart.png)

# %% [markdown]
# # Ejecutado en ibmq_santiago (5 qbits, 32 de volumen cuántico)

# %%
circuit = QuantumCircuit(3, 3)
circuit.h(0)
circuit.cx(0, 1)
circuit.cx(1, 2)
circuit.measure([0,1,2], [0,1,2])

provider = IBMQ.load_account()
backend = provider.backends.ibmq_santiago
qobj = assemble(transpile(circuit, backend=backend), backend=backend)
job = backend.run(qobj)
retrieved_job = backend.retrieve_job(job.job_id())


result = job.result()

counts = result.get_counts(circuit)
print("\nNúmero de ocurrencias: ",counts)
# Out:
# ibmqfactory.load_account:WARNING:2021-03-11 11:49:01,956: Credentials are already in use. The existing account in the session will be replaced.
# Número de ocurrencias:  {'000': 568, '001': 8, '010': 2, '011': 13, '100': 6, '101': 2, '110': 13, '111': 412}

# %% [markdown]
# ![bar-chart.png](attachment:bar-chart.png)

# %% [markdown]
# # Ejecutado en ibmq_armonk (1 qbits, 1 de volumen cuántico)

# %%
circuit = QuantumCircuit(3, 3)
circuit.h(0)
circuit.cx(0, 1)
circuit.cx(1, 2)
circuit.measure([0,1,2], [0,1,2])

provider = IBMQ.load_account()
backend = provider.backends.ibmq_armonk
qobj = assemble(transpile(circuit, backend=backend), backend=backend)
job = backend.run(qobj)
retrieved_job = backend.retrieve_job(job.job_id())


result = job.result()

counts = result.get_counts(circuit)
print("\nNúmero de ocurrencias: ",counts)

# %% [markdown]
# No me deja ejecutarlo ya que solo tiene 1 qbit
