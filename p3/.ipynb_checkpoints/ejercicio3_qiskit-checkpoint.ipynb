# %% [markdown]
# # Implementación de la QFT para 4 cubits

# %%
import numpy as np
from numpy import pi
# importing Qiskit
from qiskit import QuantumCircuit, transpile, assemble, Aer, IBMQ, execute
from qiskit.providers.ibmq import least_busy
from qiskit.tools.monitor import job_monitor
from qiskit.visualization import plot_histogram, plot_bloch_multivector

# %%
def qft_4qbits(qc):

    qc.h(3)
    qc.cp(pi/2,2,3)
    qc.cp(pi/4,1,3)
    qc.cp(pi/8,0,3)
    qc.barrier()

    qc.h(2)
    qc.cp(pi/2,1,2)
    qc.cp(pi/4,0,2)
    qc.barrier()

    qc.h(1)
    qc.cp(pi/2,0,1)
    qc.barrier()

    qc.h(0)
          
    qc.swap(0,3)
    qc.swap(1,2)

# %%
qc = QuantumCircuit(4,4)

#inicializo los cubits a |1101> (13 en binario)
qc.x(3)
qc.x(2)
qc.x(0)

sv_sim = Aer.get_backend("statevector_simulator")
qobj = assemble(qc)
statevector = sv_sim.run(qobj).result().get_statevector()
plot_bloch_multivector(statevector)

# %%
#añadimos la transformada cuántica de fourier al circuito
qc.barrier()
qft_4qbits(qc)
qc.draw()
# Out:
#      ┌───┐ ░                                     ░                           ░ »
# q_0: ┤ X ├─░──────────────────────────────■──────░────────────────────■──────░─»
#      └───┘ ░                              │      ░                    │      ░ »
# q_1: ──────░────────────────────■─────────┼──────░──────────■─────────┼──────░─»
#      ┌───┐ ░                    │         │      ░ ┌───┐┌───┴────┐┌───┴────┐ ░ »
# q_2: ┤ X ├─░──────────■─────────┼─────────┼──────░─┤ H ├┤ P(π/2) ├┤ P(π/4) ├─░─»
#      ├───┤ ░ ┌───┐┌───┴────┐┌───┴────┐┌───┴────┐ ░ └───┘└────────┘└────────┘ ░ »
# q_3: ┤ X ├─░─┤ H ├┤ P(π/2) ├┤ P(π/4) ├┤ P(π/8) ├─░───────────────────────────░─»
#      └───┘ ░ └───┘└────────┘└────────┘└────────┘ ░                           ░ »
# c: 4/══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# «                     ░ ┌───┐
# «q_0: ─────────■──────░─┤ H ├─X─
# «     ┌───┐┌───┴────┐ ░ └───┘ │
# «q_1: ┤ H ├┤ P(π/2) ├─░───X───┼─
# «     └───┘└────────┘ ░   │   │
# «q_2: ────────────────░───X───┼─
# «                     ░       │
# «q_3: ────────────────░───────X─
# «                     ░
# «c: 4/══════════════════════════
# «

# %%
sv_sim = Aer.get_backend("statevector_simulator")
qobj = assemble(qc)
statevector = sv_sim.run(qobj).result().get_statevector()
plot_bloch_multivector(statevector)

# %% [markdown]
# Como podemos ver, hemos empezado con el estado |1011> (que es 13 en binario) y podemos observar como en el qubit 0 se ha rotado 13/16, el cubit 1 ha rotado 26/16 (igual a rotar 10/16), el cubit 2 ha rotado 52/16 (igual a rotar 4/16) y el cubit 3 ha rotado 104/16 (igual a rotar 8/16).
#
# De esta manera vemos que la transformada cuántica de fourier ha funcionado.
#
# -----------------------

# %% [markdown]
# ## QFT inversa

# %%
def inverse_qft_4qbits(qc):
    
    qc.swap(0,3)
    qc.swap(1,2)
    
    qc.h(0)
    
    qc.barrier()
    qc.cp(-pi/2,0,1)
    qc.h(1)

    qc.barrier()
    qc.cp(-pi/4,0,2)
    qc.cp(-pi/2,1,2)
    qc.h(2)
    
    qc.barrier()
    qc.cp(-pi/8,0,3)
    qc.cp(-pi/4,1,3)
    qc.cp(-pi/2,2,3)  
    qc.h(3)

# %%
qc.barrier()
inverse_qft_4qbits(qc)
qc.barrier()
qc.measure([0,1,2,3],[0,1,2,3])

# %%
qc.draw()
# Out:
#      ┌───┐ ░                                     ░                           ░ »
# q_0: ┤ X ├─░──────────────────────────────■──────░────────────────────■──────░─»
#      └───┘ ░                              │      ░                    │      ░ »
# q_1: ──────░────────────────────■─────────┼──────░──────────■─────────┼──────░─»
#      ┌───┐ ░                    │         │      ░ ┌───┐┌───┴────┐┌───┴────┐ ░ »
# q_2: ┤ X ├─░──────────■─────────┼─────────┼──────░─┤ H ├┤ P(π/2) ├┤ P(π/4) ├─░─»
#      ├───┤ ░ ┌───┐┌───┴────┐┌───┴────┐┌───┴────┐ ░ └───┘└────────┘└────────┘ ░ »
# q_3: ┤ X ├─░─┤ H ├┤ P(π/2) ├┤ P(π/4) ├┤ P(π/8) ├─░───────────────────────────░─»
#      └───┘ ░ └───┘└────────┘└────────┘└────────┘ ░                           ░ »
# c: 4/══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# «                     ░ ┌───┐    ░    ┌───┐ ░                  ░            »
# «q_0: ─────────■──────░─┤ H ├─X──░──X─┤ H ├─░──────■───────────░──────■─────»
# «     ┌───┐┌───┴────┐ ░ └───┘ │  ░  │ └───┘ ░ ┌────┴────┐┌───┐ ░      │     »
# «q_1: ┤ H ├┤ P(π/2) ├─░───X───┼──░──┼───X───░─┤ P(-π/2) ├┤ H ├─░──────┼─────»
# «     └───┘└────────┘ ░   │   │  ░  │   │   ░ └─────────┘└───┘ ░ ┌────┴────┐»
# «q_2: ────────────────░───X───┼──░──┼───X───░──────────────────░─┤ P(-π/4) ├»
# «                     ░       │  ░  │       ░                  ░ └─────────┘»
# «q_3: ────────────────░───────X──░──X───────░──────────────────░────────────»
# «                     ░          ░          ░                  ░            »
# «c: 4/══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «                      ░                                        ░ ┌─┐
# «q_0: ─────────────────░──────■─────────────────────────────────░─┤M├─────────
# «                      ░      │                                 ░ └╥┘┌─┐
# «q_1: ─────■───────────░──────┼──────────■──────────────────────░──╫─┤M├──────
# «     ┌────┴────┐┌───┐ ░      │          │                      ░  ║ └╥┘┌─┐
# «q_2: ┤ P(-π/2) ├┤ H ├─░──────┼──────────┼──────────■───────────░──╫──╫─┤M├───
# «     └─────────┘└───┘ ░ ┌────┴────┐┌────┴────┐┌────┴────┐┌───┐ ░  ║  ║ └╥┘┌─┐
# «q_3: ─────────────────░─┤ P(-π/8) ├┤ P(-π/4) ├┤ P(-π/2) ├┤ H ├─░──╫──╫──╫─┤M├
# «                      ░ └─────────┘└─────────┘└─────────┘└───┘ ░  ║  ║  ║ └╥┘
# «c: 4/═════════════════════════════════════════════════════════════╩══╩══╩══╩═
# «                                                                  0  1  2  3

# %%
sim = Aer.get_backend("qasm_simulator")
job = execute(qc,sim,shots=1000)
result = job.result()
counts = result.get_counts(qc)

print(counts)
# Out:
# {'1101': 1000}

# %% [markdown]
# Al aplicar la inversa a nuestra qft, un 100% de las veces obtenemos el resultado original |1101> por lo que podemos ver como nuestra QFT funciona y la QFT inversa también

# %% [markdown]
# # Implementación de la AQFT para 4 cubits y 2 rotaciones

# %%
def aqft_4qbits_2rot(qc):

    qc.h(3)
    qc.cp(pi/2,2,3)
    qc.cp(pi/4,1,3)
    qc.barrier()

    qc.h(2)
    qc.cp(pi/2,1,2)
    qc.cp(pi/4,0,2)
    qc.barrier()

    qc.h(1)
    qc.cp(pi/2,0,1)
    qc.barrier()

    qc.h(0)
          
    qc.swap(0,3)
    qc.swap(1,2)

# %%
qc = QuantumCircuit(4)

#inicializo los cubits a |1101> (13 en binario)
qc.x(3)
qc.x(2)
qc.x(0)

sv_sim = Aer.get_backend("statevector_simulator")
qobj = assemble(qc)
statevector = sv_sim.run(qobj).result().get_statevector()
plot_bloch_multivector(statevector)

# %%
#añadimos la transformada cuántica de fourier al circuito
qc.barrier()
aqft_4qbits_2rot(qc)
qc.draw()
# Out:
#      ┌───┐ ░                           ░                           ░      »
# q_0: ┤ X ├─░───────────────────────────░────────────────────■──────░──────»
#      └───┘ ░                           ░                    │      ░ ┌───┐»
# q_1: ──────░────────────────────■──────░──────────■─────────┼──────░─┤ H ├»
#      ┌───┐ ░                    │      ░ ┌───┐┌───┴────┐┌───┴────┐ ░ └───┘»
# q_2: ┤ X ├─░──────────■─────────┼──────░─┤ H ├┤ P(π/2) ├┤ P(π/4) ├─░──────»
#      ├───┤ ░ ┌───┐┌───┴────┐┌───┴────┐ ░ └───┘└────────┘└────────┘ ░      »
# q_3: ┤ X ├─░─┤ H ├┤ P(π/2) ├┤ P(π/4) ├─░───────────────────────────░──────»
#      └───┘ ░ └───┘└────────┘└────────┘ ░                           ░      »
# «                ░ ┌───┐
# «q_0: ────■──────░─┤ H ├─X─
# «     ┌───┴────┐ ░ └───┘ │
# «q_1: ┤ P(π/2) ├─░───X───┼─
# «     └────────┘ ░   │   │
# «q_2: ───────────░───X───┼─
# «                ░       │
# «q_3: ───────────░───────X─
# «                ░

# %%
sv_sim = Aer.get_backend("statevector_simulator")
qobj = assemble(qc)
statevector = sv_sim.run(qobj).result().get_statevector()
plot_bloch_multivector(statevector)

# %% [markdown]
# ## ¡IMPORTANTE!
#
# Hablar cuando lo ejecute en un backend real sobre como la aqft puede llegar a ser mas precisa que la QFT completa ante la presencia de ruido pese a no hacer todas las rotaciones
