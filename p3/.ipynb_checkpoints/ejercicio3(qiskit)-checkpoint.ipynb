# %% [markdown]
# # Implementación de la QFT para 4 cubits

# %%
import numpy as np
from numpy import pi
# importing Qiskit
from qiskit import QuantumCircuit, transpile, assemble, Aer, IBMQ
from qiskit.providers.ibmq import least_busy
from qiskit.tools.monitor import job_monitor
from qiskit.visualization import plot_histogram, plot_bloch_multivector

# %%
def qft_4qbits(qc):

    qc.h(3)
    qc.cp(pi/2,2,3)
    qc.cp(pi/4,1,3)
    qc.cp(pi/8,0,3)
    qc.barrier()

    qc.h(2)
    qc.cp(pi/2,1,2)
    qc.cp(pi/4,0,2)
    qc.barrier()

    qc.h(1)
    qc.cp(pi/2,0,1)
    qc.barrier()

    qc.h(0)
          
    qc.swap(0,3)
    qc.swap(1,2)

# %%
#esta es la que no me funciona, preguntarle al profe pourquoi

def qft_4qbits(qc):

    qc.h(0)
    qc.cp(pi/2,1,0)
    qc.cp(pi/4,2,0)
    qc.cp(pi/8,3,0)
    qc.barrier()
    
    qc.h(1)
    qc.cp(pi/2,2,1)
    qc.cp(pi/4,3,1)
    qc.barrier()

    qc.h(2)
    qc.cp(pi/2,3,2)
    qc.barrier()

    qc.h(3)

# %%
qc = QuantumCircuit(4)

#inicializo los cubits a |1101> (13 en binario)
qc.x(3)
qc.x(2)
qc.x(0)

qc.draw()
# Out:
#      ┌───┐
# q_0: ┤ X ├
#      └───┘
# q_1: ─────
#      ┌───┐
# q_2: ┤ X ├
#      ├───┤
# q_3: ┤ X ├
#      └───┘

# %%
sv_sim = Aer.get_backend("statevector_simulator")
qobj = assemble(qc)
statevector = sv_sim.run(qobj).result().get_statevector()
plot_bloch_multivector(statevector)

# %%
#añadimos la transformada cuántica de fourier al circuito
qc.barrier()
qft_4qbits(qc)
qc.draw()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-b14345919677> in <module>
#       1 #añadimos la transformada cuántica de fourier al circuito
#       2 qc.barrier()
# ----> 3 qft_4qbits(qc)
#       4 qc.draw()
#
# <ipython-input-55-09e72f784d9e> in qft_4qbits(qc)
#       2
#       3     qc.h(3)
# ----> 4     qc.cz(1,0)**2
#       5     qc.cp(pi/4,1,3)
#       6     qc.cp(pi/8,0,3)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'InstructionSet' and 'int'

# %%
sv_sim = Aer.get_backend("statevector_simulator")
qobj = assemble(qc)
statevector = sv_sim.run(qobj).result().get_statevector()
plot_bloch_multivector(statevector)

# %% [markdown]
# Como podemos ver, hemos empezado con el estado |1011> (que es 13 en binario) y podemos observar como en el qubit 0 se ha rotado 13/16, el cubit 1 ha rotado 26/16 (igual a rotar 10/16), el cubit 2 ha rotado 52/16 (igual a rotar 4/16) y el cubit 3 ha rotado 104/16 (igual a rotar 8/16).
#
# De esta manera vemos que la transformada cuántica de fourier ha funcionado.
#
# -----------------------

# %% [markdown]
# # Implementación de la AQFT para 4 cubits y 2 rotaciones

# %%
def aqft_4qbits_2rot(qc):

    qc.h(0)
    qc.cz(1,0)**2
    qc.cp(2,0)
    qc.barrier()

    qc.h()
    qc.cp(pi/,,)
    qc.cp(pi/,,)
    qc.barrier()

    qc.h()
    qc.cp(pi/,,)
    qc.barrier()

    qc.h()
# Out:
#   File "<ipython-input-54-2b19d5609804>", line 9
#     qc.cp(pi/,,)
#              ^
# SyntaxError: invalid syntax
